# %%
import pandas as pd

# %%
INPUT_FILE_PATH = "https://datahub.io/JohnSnowLabs/drinking-water-quality-distribution-monitoring-data/r/drinking-water-quality-distribution-monitoring-data-csv.csv"

# %%
df = pd.read_csv(INPUT_FILE_PATH)

# %%
df
# Out:
#        Sample_Number Sample_Date Sample_Site Sample_Class  \
# 0                NaN  2015-01-01        1S07  Operational
# 1                NaN  2015-01-01        1S04  Operational
# 2                NaN  2015-01-01       1S03A  Operational
# 3                NaN  2015-01-01       1S03B  Operational
# 4                NaN  2015-01-01       11550   Compliance
# 5                NaN  2015-01-01       13850   Compliance
# 6                NaN  2015-01-01       15550   Compliance
# 7                NaN  2015-01-01       17550   Compliance
# 8                NaN  2015-01-01       20900  Operational
# 9                NaN  2015-01-01       21850   Compliance
# 10               NaN  2015-01-01       22050   Compliance
# 11               NaN  2015-01-01       23350   Compliance
# 12               NaN  2015-01-01       23650   Compliance
# 13               NaN  2015-01-01       24150   Compliance
# 14               NaN  2015-01-01       25250   Compliance
# ...
